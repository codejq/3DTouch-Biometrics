# %% [markdown]
# <a href="https://colab.research.google.com/github/codejq/3DTouch-Biometrics/blob/master/keras2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load the dataset
dataset = loadtxt('/content/drive/My Drive/pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]
xtrain = X[:700, :]
xtest = X[700:, :]
ytrain = y[:700]
ytest = y[700:]

# %%
# define the keras model
model = Sequential()
model.add(Dense(2024, input_dim=8, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(xtrain, ytrain, epochs=500, batch_size=50)
# Out:
# Epoch 1/500
# 14/14 [==============================] - 0s 27ms/step - loss: 13.2859 - accuracy: 0.5229
# Epoch 2/500
# 14/14 [==============================] - 0s 27ms/step - loss: 2.3705 - accuracy: 0.6057
# Epoch 3/500
# 14/14 [==============================] - 0s 26ms/step - loss: 1.1699 - accuracy: 0.6614
# Epoch 4/500
# 14/14 [==============================] - 0s 27ms/step - loss: 0.9710 - accuracy: 0.5871
# Epoch 5/500
# 14/14 [==============================] - 0s 27ms/step - loss: 0.7500 - accuracy: 0.6786
# Epoch 6/500
# 14/14 [==============================] - 0s 27ms/step - loss: 0.6095 - accuracy: 0.6829
# Epoch 7/500
# 14/14 [==============================] - 0s 27ms/step - loss: 0.5574 - accuracy: 0.7257
# Epoch 8/500
# 14/14 [==============================] - 0s 28ms/step - loss: 0.5704 - accuracy: 0.7086
# Epoch 9/500
# 14/14 [==============================] - 0s 26ms/step - loss: 0.5738 - accuracy: 0.7114
# Epoch 10/500
# ...

# %%
# evaluate the keras model
_, accuracy = model.evaluate(xtest, ytest)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3155 - accuracy: 0.7794
# Accuracy: 77.94
